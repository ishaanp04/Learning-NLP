# %%
import nltk

# %%
corpus = """This is a sample corpus that i am writing without thinking even for a second.
Nevermind i just thought for like 30 seconds.
I am trying to learn NLP from Krish Naik's youtube channel.
"""
print(corpus)
# Out:
# This is a sample corpus that i am writing without thinking even for a second.
# Nevermind i just thought for like 30 seconds.
# I am trying to learn NLP from Krish Naik's youtube channel.

# %%
# Paragraphs -> Sentences
import nltk
from nltk.tokenize import sent_tokenize
# nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
documents = sent_tokenize(corpus)
for sentence in documents:
  print(sentence)
# Out:
# This is a sample corpus that i am writing without thinking even for a second.
# Nevermind i just thought for like 30 seconds.
# I am trying to learn NLP from Krish Naik's youtube channel.

# %%
# Paragraph -> Words
# Sentence -> Words
from nltk.tokenize import word_tokenize

# %%
print(word_tokenize(corpus))
# Out:
# ['This', 'is', 'a', 'sample', 'corpus', 'that', 'i', 'am', 'writing', 'without', 'thinking', 'even', 'for', 'a', 'second', '.', 'Nevermind', 'i', 'just', 'thought', 'for', 'like', '30', 'seconds', '.', 'I', 'am', 'trying', 'to', 'learn', 'NLP', 'from', 'Krish', 'Naik', "'s", 'youtube', 'channel', '.']

# %%
for sentence in documents:
  print(word_tokenize(sentence))
# Out:
# ['This', 'is', 'a', 'sample', 'corpus', 'that', 'i', 'am', 'writing', 'without', 'thinking', 'even', 'for', 'a', 'second', '.']
# ['Nevermind', 'i', 'just', 'thought', 'for', 'like', '30', 'seconds', '.']
# ['I', 'am', 'trying', 'to', 'learn', 'NLP', 'from', 'Krish', 'Naik', "'s", 'youtube', 'channel', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
